# %%
script 定义:
js对象内部元素都是以键值对的方式存储属性和方法
a = {key:vaule......} 或者    var a = new Object()


优先级从高到低: 行内 id class
    行内式: 用于事件
    内嵌式: 通过id来
        type默认类型是text/javascript
    外链式:

    
js基础:
    定义变量:使用var
        数学运算符:数据运算时是从左到右运算,int和字符串可以相加相加时,同意转换成字符串拼接
            
            +-*/    100+200+'300' 输出"300300" 先相加得到300  和字符串相加时变成字符串拼接
            += *=
            
            
            
            
            
            
    数据类型:
        number: var a = 123
        布尔值:  var a = true b=false
        字符串:  var a = 'abc'
        未定义类型:var a;  undefined类型
        空对象:  var a = null   相当于py中的None
        对象  :  var a = {name:oldboy,age:18}  调用使用 a.name

    函数:
        定义:
            使用function func_name(){  ......   } 定义,传参可以少传也不会报错,没有参数的变量是undefined类型
    变量作用域:
        跟python差不多,函数内部修改全局变量不需要加globa
        
    条件语句:
        条件判断:
            if(3>1){
            ......执行块
            }
            else if
            
            else
        比较运算:
            a==b:  只比较数值需要==    123=='123'  true
            a===b: 类型包括值也相等需要===
        
        逻辑判断:
            && and
            || or
            !  not

和html的联动:
    使网页加载完自动执行的函数:事件与函数绑定在一起
        windows.onload = function_name(){......}
        事件 = 函数
        
        
    得到对象/标签 的'控件':
        var a = document.getelement(标签id)


    改变控件:
        改变属性:
            obj.value = ...
        改变样式:
            obj.style.background = '#ffffff'
            obg.classname = class标签
    获得标签的内容:
        console.log(控件.innerhtml)
        改变标签的内容:
            控件.innerhtml = 新内容
            
            
js数组:
    定义:
        var a = [1,2,3,4,'a','b']     vaa b = new Array(1,2,3,4,5)
        console.log(a[1]) 通过下标获取元素
        console.log(length[a]) 得到a的长度
    增删:
        写入数据:
            a.push(1)   添加数据到最后
        删除数据:
            a.pop() 默认删除数据最后一个
        
        根据下标添加和删除:
            a.splice(start,次数) 从start开始的下标位置 开始删除,删除几次
            a.splice(start,0,数据,数据) 从下标start的位置 删除0个  添加 两个 数据

循环:
    for(初始值,出口条件,更改条件值){
        ......
    }
        
    while(条件条件){
        ......
        }
    
    
    do{
    代码块
    }while(判断条件)
    
    
    
字符串拼接:
    var a= 'abc'
    var b = '123'
    var c = a+b
    
    var a= 456  var b='1'      a+b 输出是4561
    100+200+'300' 输出"300300" 先相加得到300  和字符串相加时变成字符串拼接

# %%
定时器:
    一定时间内执行一段代码
    setTimeout()
    setInterval()
    
    clearTimeout()
    clearInterval

# %%
事件:
    onclick 点击鼠标
    alert 警报 弹出 网页
    console.log(obj) 打印obj到控制台
